# %%
from sympy.polys.numberfields.galois_resolvents import generate_lambda_lookup

print("Jupyter Notebook 是一个非常强大的交互式计算环境，可以用于创建和共享包含实时代码、方程、可视化和叙述性文本的文档。以下是一些基本的使用方法：")

print("\n1. 创建一个新的 Notebook:")
print("   - 打开 Jupyter Notebook 服务器，点击 'New' 按钮，然后选择 'Python 3' 来创建一个新的 Notebook。")

print("\n2. 添加和编辑单元格:")
print("   - 在 Notebook 中，你可以添加两种类型的单元格：代码单元格和 Markdown 单元格。")
print("   - 代码单元格用于编写和运行 Python 代码。")
print("   - Markdown 单元格用于编写格式化的文本，支持 Markdown 语法。")
print("   - 你可以通过点击工具栏上的 '+' 按钮来添加新的单元格。")
print("   - 通过点击单元格左侧的类型标识 (Code 或 Markdown)，可以在代码单元格和 Markdown 单元格之间切换。")

print("\n3. 运行单元格:")
print("   - 选中一个单元格后，按 `Shift + Enter` 键来运行它。")
print("   - 对于代码单元格，这将执行其中的代码并显示输出。")
print("   - 对于 Markdown 单元格，这将渲染 Markdown 文本。")

print("\n4. 导入和导出 Notebook:")
print("   - 你可以通过点击 'File' -> 'Download as' 来将 Notebook 导出为不同的格式，如 HTML、PDF 或者 Python 脚本。")
print("   - 你也可以通过点击 'File' -> 'Upload' 来上传现有的 Notebook 文件。")

print("\n5. 使用魔法命令:")
print("   - Jupyter Notebook 提供了一些特殊的命令，称为魔法命令，以 `%` 开头。")
print("   - 例如，`%matplotlib inline` 可以让你在 Notebook 中直接显示图表。")
print("   - `!` 命令可以让你在 Notebook 中运行 shell 命令，例如 `!ls`。")

print("\n6. 安装和管理包:")
print("   - 你可以使用 `!pip install <package_name>` 来安装 Python 包。")
print("   - 例如，`!pip install numpy` 将安装 NumPy 包。")

print("\n7. 查看帮助文档:")
print("   - 你可以使用 `?` 来查看函数或对象的帮助文档。")
print("   - 例如，`numpy.array?` 将显示 `numpy.array` 的帮助文档。")

print("\n8. 保存和关闭 Notebook:")
print("   - 记得经常保存你的工作，可以通过点击 'File' -> 'Save and Checkpoint' 或者使用快捷键 `Ctrl + S`。")
# Out:
# Jupyter Notebook 是一个非常强大的交互式计算环境，可以用于创建和共享包含实时代码、方程、可视化和叙述性文本的文档。以下是一些基本的使用方法：
#
# 1. 创建一个新的 Notebook:
#    - 打开 Jupyter Notebook 服务器，点击 'New' 按钮，然后选择 'Python 3' 来创建一个新的 Notebook。
#
# 2. 添加和编辑单元格:
#    - 在 Notebook 中，你可以添加两种类型的单元格：代码单元格和 Markdown 单元格。
#    - 代码单元格用于编写和运行 Python 代码。
#    - Markdown 单元格用于编写格式化的文本，支持 Markdown 语法。
#    - 你可以通过点击工具栏上的 '+' 按钮来添加新的单元格。
#    - 通过点击单元格左侧的类型标识 (Code 或 Markdown)，可以在代码单元格和 Markdown 单元格之间切换。
#
# 3. 运行单元格:
#    - 选中一个单元格后，按 `Shift + Enter` 键来运行它。
#    - 对于代码单元格，这将执行其中的代码并显示输出。
#    - 对于 Markdown 单元格，这将渲染 Markdown 文本。
#
# 4. 导入和导出 Notebook:
#    - 你可以通过点击 'File' -> 'Download as' 来将 Notebook 导出为不同的格式，如 HTML、PDF 或者 Python 脚本。
#    - 你也可以通过点击 'File' -> 'Upload' 来上传现有的 Notebook 文件。
#
# 5. 使用魔法命令:
#    - Jupyter Notebook 提供了一些特殊的命令，称为魔法命令，以 `%` 开头。
#    - 例如，`%matplotlib inline` 可以让你在 Notebook 中直接显示图表。
#    - `!` 命令可以让你在 Notebook 中运行 shell 命令，例如 `!ls`。
#
# 6. 安装和管理包:
#    - 你可以使用 `!pip install <package_name>` 来安装 Python 包。
# ...

# %%
print("   - 关闭 Notebook 时，点击 'File' -> 'Close and Halt'。")
# Out:
#    - 关闭 Notebook 时，点击 'File' -> 'Close and Halt'。
